# %%
# Jeopardy Questions
# work with a dataset of Jeopardy questions to figure out some patterns in the questions that could help you win.
import pandas
jeopardy = pandas.read_csv("jeopardy.csv", encoding = "ISO-8859-1")
print(jeopardy.head())
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  12/31/2004  Jeopardy!                          HISTORY  $200
# 1         4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  12/31/2004  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
# Print out the columns of jeopardy using jeopardy.columns.
print(jeopardy.columns)
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
# Remove the spaces in each item in jeopardy.columns
# Assign the result back to jeopardy.columns to fix the column names in jeopardy
jeopardy.columns = ['Show Number', 'Air Date', 'Round', 'Category', 'Value','Question', 'Answer']

# %%
# Normalizing Text
# Write a function to normalize questions and answers
# Convert the string to lowercase and remove all punctuation in the string.
import re

def normalized_text(string):
    string = string.lower()
    # ^ matches the start of the string
    # \s matches Unicode whitespace characters (which includes [ \t\n\r\f\v], and also many other characters
    string = re.sub("[^A-Za-z0-9\s]","", string)
    return string

# %%
# Normalize the Question column
jeopardy["clean_question"] = jeopardy["Question"].apply(normalized_text)

# Normalize the Answer column
jeopardy["clean_answer"] = jeopardy["Answer"].apply(normalized_text)

# %%
# Normalizing Columns
# Write a function to normalize dollar values.
# Remove any punctuation in the string, convert the string to an integer.
# If the conversion has an error, assign 0 instead
def normalized_value(string):
    string = re.sub("[^A-Za-z0-9\s]","", string)
    try:
        string = int(string)
    except Exception:
        string = 0
    return string

# %%
# Normalize the Value column.
jeopardy["clean_value"] = jeopardy["Value"].apply(normalized_value)

# %%
# Use the pandas.to_datetime function to convert the Air Date column to a datetime column.
jeopardy["Air Date"] = pandas.to_datetime(jeopardy["Air Date"])

# %%
jeopardy
# Out:
#         Show Number   Air Date             Round  \
# 0              4680 2004-12-31         Jeopardy!
# 1              4680 2004-12-31         Jeopardy!
# 2              4680 2004-12-31         Jeopardy!
# 3              4680 2004-12-31         Jeopardy!
# 4              4680 2004-12-31         Jeopardy!
# 5              4680 2004-12-31         Jeopardy!
# 6              4680 2004-12-31         Jeopardy!
# 7              4680 2004-12-31         Jeopardy!
# 8              4680 2004-12-31         Jeopardy!
# 9              4680 2004-12-31         Jeopardy!
# 10             4680 2004-12-31         Jeopardy!
# 11             4680 2004-12-31         Jeopardy!
# 12             4680 2004-12-31         Jeopardy!
# 13             4680 2004-12-31         Jeopardy!
# 14             4680 2004-12-31         Jeopardy!
# 15             4680 2004-12-31         Jeopardy!
# 16             4680 2004-12-31         Jeopardy!
# 17             4680 2004-12-31         Jeopardy!
# 18             4680 2004-12-31         Jeopardy!
# 19             4680 2004-12-31         Jeopardy!
# 20             4680 2004-12-31         Jeopardy!
# 21             4680 2004-12-31         Jeopardy!
# 22             4680 2004-12-31         Jeopardy!
# 23             4680 2004-12-31         Jeopardy!
# 24             4680 2004-12-31         Jeopardy!
# 25             4680 2004-12-31         Jeopardy!
# 26             4680 2004-12-31         Jeopardy!
# 27             4680 2004-12-31         Jeopardy!
# 28             4680 2004-12-31         Jeopardy!
# 29             4680 2004-12-31  Double Jeopardy!
# ...             ...        ...               ...
# 216900         4999 2006-05-11  Double Jeopardy!
# 216901         4999 2006-05-11  Double Jeopardy!
# 216902         4999 2006-05-11  Double Jeopardy!
# 216903         4999 2006-05-11  Double Jeopardy!
# 216904         4999 2006-05-11  Double Jeopardy!
# 216905         4999 2006-05-11  Double Jeopardy!
# 216906         4999 2006-05-11  Double Jeopardy!
# 216907         4999 2006-05-11  Double Jeopardy!
# 216908         4999 2006-05-11  Double Jeopardy!
# 216909         4999 2006-05-11  Double Jeopardy!
# 216910         4999 2006-05-11  Double Jeopardy!
# 216911         4999 2006-05-11  Double Jeopardy!
# 216912         4999 2006-05-11  Double Jeopardy!
# 216913         4999 2006-05-11  Double Jeopardy!
# 216914         4999 2006-05-11  Double Jeopardy!
# 216915         4999 2006-05-11  Double Jeopardy!
# 216916         4999 2006-05-11  Double Jeopardy!
# 216917         4999 2006-05-11  Double Jeopardy!
# 216918         4999 2006-05-11  Double Jeopardy!
# 216919         4999 2006-05-11  Double Jeopardy!
# 216920         4999 2006-05-11  Double Jeopardy!
# 216921         4999 2006-05-11  Double Jeopardy!
# 216922         4999 2006-05-11  Double Jeopardy!
# 216923         4999 2006-05-11  Double Jeopardy!
# 216924         4999 2006-05-11  Double Jeopardy!
# 216925         4999 2006-05-11  Double Jeopardy!
# 216926         4999 2006-05-11  Double Jeopardy!
# 216927         4999 2006-05-11  Double Jeopardy!
# 216928         4999 2006-05-11  Double Jeopardy!
# 216929         4999 2006-05-11   Final Jeopardy!
#
#                                Category    Value  \
# 0                               HISTORY    $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES    $200
# 2           EVERYBODY TALKS ABOUT IT...    $200
# 3                      THE COMPANY LINE    $200
# 4                   EPITAPHS & TRIBUTES    $200
# 5                        3-LETTER WORDS    $200
# 6                               HISTORY    $400
# 7       ESPN's TOP 10 ALL-TIME ATHLETES    $400
# 8           EVERYBODY TALKS ABOUT IT...    $400
# 9                      THE COMPANY LINE    $400
# 10                  EPITAPHS & TRIBUTES    $400
# 11                       3-LETTER WORDS    $400
# 12                              HISTORY    $600
# 13      ESPN's TOP 10 ALL-TIME ATHLETES    $600
# 14          EVERYBODY TALKS ABOUT IT...    $600
# 15                     THE COMPANY LINE    $600
# 16                  EPITAPHS & TRIBUTES    $600
# 17                       3-LETTER WORDS    $600
# 18                              HISTORY    $800
# 19      ESPN's TOP 10 ALL-TIME ATHLETES    $800
# 20          EVERYBODY TALKS ABOUT IT...    $800
# 21                     THE COMPANY LINE    $800
# 22                  EPITAPHS & TRIBUTES  $2,000
# 23                       3-LETTER WORDS    $800
# 24                              HISTORY  $1,000
# 25      ESPN's TOP 10 ALL-TIME ATHLETES  $1,000
# 26                     THE COMPANY LINE  $1,000
# 27                  EPITAPHS & TRIBUTES  $1,000
# 28                       3-LETTER WORDS  $1,000
# 29           DR. SEUSS AT THE MULTIPLEX    $400
# ...                                 ...      ...
# 216900                     OFF-BROADWAY    $400
# 216901                   RIDDLE ME THIS    $400
# 216902                        "T" BIRDS    $400
# 216903           AUTHORS IN THEIR YOUTH    $400
# 216904                       QUOTATIONS    $400
# 216905                   WORLD CAPITALS    $800
# 216906                     OFF-BROADWAY    $800
# 216907                   RIDDLE ME THIS    $800
# 216908                        "T" BIRDS    $800
# 216909           AUTHORS IN THEIR YOUTH    $800
# 216910                       QUOTATIONS    $800
# 216911                   WORLD CAPITALS  $1,200
# 216912                     OFF-BROADWAY  $1,200
# 216913                   RIDDLE ME THIS  $1,200
# 216914                        "T" BIRDS  $1,200
# 216915           AUTHORS IN THEIR YOUTH  $1,200
# 216916                       QUOTATIONS  $2,200
# 216917                   WORLD CAPITALS  $3,400
# 216918                     OFF-BROADWAY  $1,600
# 216919                   RIDDLE ME THIS  $1,600
# 216920                        "T" BIRDS  $1,600
# 216921           AUTHORS IN THEIR YOUTH  $1,600
# 216922                       QUOTATIONS  $1,600
# 216923                   WORLD CAPITALS  $2,000
# 216924                     OFF-BROADWAY  $2,000
# 216925                   RIDDLE ME THIS  $2,000
# 216926                        "T" BIRDS  $2,000
# 216927           AUTHORS IN THEIR YOUTH  $2,000
# 216928                       QUOTATIONS  $2,000
# 216929                   HISTORIC NAMES     None
#
#                                                  Question  \
# 0       For the last 8 years of his life, Galileo was ...
# 1       No. 2: 1912 Olympian; football star at Carlisl...
# 2       The city of Yuma in this state has a record av...
# 3       In 1963, live on "The Art Linkletter Show", th...
# 4       Signer of the Dec. of Indep., framer of the Co...
# 5       In the title of an Aesop fable, this insect sh...
# 6       Built in 312 B.C. to link Rome & the South of ...
# 7       No. 8: 30 steals for the Birmingham Barons; 2,...
# 8       In the winter of 1971-72, a record 1,122 inche...
# 9       This housewares store was named for the packag...
# 10                                       "And away we go"
# 11      Cows regurgitate this from the first stomach t...
# 12      In 1000 Rajaraja I of the Cholas battled to ta...
# 13      No. 1: Lettered in hoops, football & lacrosse ...
# 14      On June 28, 1994 the nat'l weather service beg...
# 15      This company's Accutron watch, introduced in 1...
# 16      Outlaw: "Murdered by a traitor and a coward wh...
# 17      A small demon, or a mischievous child (who mig...
# 18      Karl led the first of these Marxist organizati...
# 19      No. 10: FB/LB for Columbia U. in the 1920s; MV...
# 20      Africa's lowest temperature was 11 degrees bel...
# 21      Edward Teller & this man partnered in 1898 to ...
# 22      1939 Oscar winner: "...you are a credit to you...
# 23      In geologic time one of these, shorter than an...
# 24      This Asian political party was founded in 1885...
# 25      No. 5: Only center to lead the NBA in assists;...
# 26      The Kirschner brothers, Don & Bill, named this...
# 27      Revolutionary War hero: "His spirit is in Verm...
# 28      A single layer of paper, or to perform one's c...
# 29      <a href="http://www.j-archive.com/media/2004-1...
# ...                                                   ...
# 216900  This Baldwin brother was extremely entertainin...
# 216901  He used the strength of his mind when he propo...
# 216902  Common species of this duck include blue-winge...
# 216903  As a child, Joseph Conrad pointed to the cente...
# 216904  In 1981 he quipped, "You can tell a lot about ...
# 216905  It has a museum devoted to composer Zoltan Kodaly
# 216906  "Red Light Winter" centers on a love triangle ...
# 216907  Sphinx: What animal walks on 4 legs in the mor...
# 216908  Toco, the largest species of this colorful bir...
# 216909  Poet Gregory Corso went on the beat path after...
# 216910  In his prime this athlete said, It's hard to b...
# 216911             It's home to the Holmenkollen ski jump
# 216912  We'd like to "enlighten" you about the musical...
# 216913  He created the musical riddles called the "Eni...
# 216914  One species of this bird breeds in the Arctic ...
# 216915  In his teens he worked in an assistant D.A.'s ...
# 216916  Oscar Wilde called this 4-letter word "the cur...
# 216917    Guyanese capital named for a Hanoverian monarch
# 216918  A naughty 18th c. novel originally titled "Mem...
# 216919  If this riddling Belgian surrealist painter, b...
# 216920  Nightingales & robins belong to this family of...
# 216921  Her hotsy-totsy diaries trace back to one she ...
# 216922  A motto of hers was "in politics, if you want ...
# 216923                         It's on the Suriname River
# 216924  In 2006 the cast of this long-running hit emba...
# 216925  This Puccini opera turns on the solution to 3 ...
# 216926  In North America this term is properly applied...
# 216927  In Penny Lane, where this "Hellraiser" grew up...
# 216928  From Ft. Sill, Okla. he made the plea, Arizona...
# 216929  A silent movie title includes the last name of...
#
#                                                    Answer  \
# 0                                              Copernicus
# 1                                              Jim Thorpe
# 2                                                 Arizona
# 3                                              McDonald's
# 4                                              John Adams
# 5                                                 the ant
# 6                                          the Appian Way
# 7                                          Michael Jordan
# 8                                              Washington
# 9                                          Crate & Barrel
# 10                                         Jackie Gleason
# 11                                                the cud
# 12                                  Ceylon (or Sri Lanka)
# 13                                              Jim Brown
# 14                                           the UV index
# 15                                                 Bulova
# 16                                            Jesse James
# 17                                                    imp
# 18                                      the International
# 19                                           (Lou) Gehrig
# 20                                                Morocco
# 21                                          (Paul) Bonwit
# 22      Hattie McDaniel (for her role in Gone with the...
# 23                                                    era
# 24                                     the Congress Party
# 25                                     (Wilt) Chamberlain
# 26                                                     K2
# 27                                            Ethan Allen
# 28                                                    ply
# 29                                                 Horton
# ...                                                   ...
# 216900                                       Alec Baldwin
# 216901                                             Samson
# 216902                                           the teal
# 216903                                             Africa
# 216904                                      Ronald Reagan
# 216905                                           Budapest
# 216906                                          Amsterdam
# 216907                                                man
# 216908                                           a toucan
# 216909                                     Allen Ginsberg
# 216910                                       Muhammad Ali
# 216911                                               Oslo
# 216912                                         Siddhartha
# 216913                                     (Edward) Elgar
# 216914                                             a tern
# 216915                             (Erle Stanley) Gardner
# 216916                                               work
# 216917                                         Georgetown
# 216918                                         Fanny Hill
# 216919                                           Magritte
# 216920                                           thrushes
# 216921                                         Ana??s Nin
# 216922                                (Margaret) Thatcher
# 216923                                         Paramaribo
# 216924                                              Stomp
# 216925                                           Turandot
# 216926                                         a titmouse
# 216927                                       Clive Barker
# 216928                                           Geronimo
# 216929                     Grigori Alexandrovich Potemkin
#
#                                            clean_question  \
# 0       for the last 8 years of his life galileo was u...
# 1       no 2 1912 olympian football star at carlisle i...
# 2       the city of yuma in this state has a record av...
# 3       in 1963 live on the art linkletter show this c...
# 4       signer of the dec of indep framer of the const...
# 5       in the title of an aesop fable this insect sha...
# 6       built in 312 bc to link rome  the south of ita...
# 7       no 8 30 steals for the birmingham barons 2306 ...
# 8       in the winter of 197172 a record 1122 inches o...
# 9       this housewares store was named for the packag...
# 10                                         and away we go
# 11      cows regurgitate this from the first stomach t...
# 12      in 1000 rajaraja i of the cholas battled to ta...
# 13      no 1 lettered in hoops football  lacrosse at s...
# 14      on june 28 1994 the natl weather service began...
# 15      this companys accutron watch introduced in 196...
# 16      outlaw murdered by a traitor and a coward whos...
# 17      a small demon or a mischievous child who might...
# 18      karl led the first of these marxist organizati...
# 19      no 10 fblb for columbia u in the 1920s mvp for...
# 20      africas lowest temperature was 11 degrees belo...
# 21      edward teller  this man partnered in 1898 to s...
# 22      1939 oscar winner you are a credit to your cra...
# 23      in geologic time one of these shorter than an ...
# 24      this asian political party was founded in 1885...
# 25      no 5 only center to lead the nba in assists tr...
# 26      the kirschner brothers don  bill named this sk...
# 27      revolutionary war hero his spirit is in vermon...
# 28      a single layer of paper or to perform ones cra...
# 29      a hrefhttpwwwjarchivecommedia20041231dj23mp3be...
# ...                                                   ...
# 216900  this baldwin brother was extremely entertainin...
# 216901  he used the strength of his mind when he propo...
# 216902  common species of this duck include bluewinged...
# 216903  as a child joseph conrad pointed to the center...
# 216904  in 1981 he quipped you can tell a lot about a ...
# 216905  it has a museum devoted to composer zoltan kodaly
# 216906  red light winter centers on a love triangle th...
# 216907  sphinx what animal walks on 4 legs in the morn...
# 216908  toco the largest species of this colorful bird...
# 216909  poet gregory corso went on the beat path after...
# 216910  in his prime this athlete said its hard to be ...
# 216911              its home to the holmenkollen ski jump
# 216912  wed like to enlighten you about the musical si...
# 216913  he created the musical riddles called the enig...
# 216914  one species of this bird breeds in the arctic ...
# 216915  in his teens he worked in an assistant das off...
# 216916  oscar wilde called this 4letter word the curse...
# 216917    guyanese capital named for a hanoverian monarch
# 216918  a naughty 18th c novel originally titled memoi...
# 216919  if this riddling belgian surrealist painter bo...
# 216920  nightingales  robins belong to this family of ...
# 216921  her hotsytotsy diaries trace back to one she b...
# 216922  a motto of hers was in politics if you want an...
# 216923                          its on the suriname river
# 216924  in 2006 the cast of this longrunning hit embar...
# 216925  this puccini opera turns on the solution to 3 ...
# 216926  in north america this term is properly applied...
# 216927  in penny lane where this hellraiser grew up th...
# 216928  from ft sill okla he made the plea arizona is ...
# 216929  a silent movie title includes the last name of...
#
#                                              clean_answer  clean_value
# 0                                              copernicus          200
# 1                                              jim thorpe          200
# 2                                                 arizona          200
# 3                                               mcdonalds          200
# 4                                              john adams          200
# 5                                                 the ant          200
# 6                                          the appian way          400
# 7                                          michael jordan          400
# 8                                              washington          400
# 9                                           crate  barrel          400
# 10                                         jackie gleason          400
# 11                                                the cud          400
# 12                                    ceylon or sri lanka          600
# 13                                              jim brown          600
# 14                                           the uv index          600
# 15                                                 bulova          600
# 16                                            jesse james          600
# 17                                                    imp          600
# 18                                      the international          800
# 19                                             lou gehrig          800
# 20                                                morocco          800
# 21                                            paul bonwit          800
# 22      hattie mcdaniel for her role in gone with the ...         2000
# 23                                                    era          800
# 24                                     the congress party         1000
# 25                                       wilt chamberlain         1000
# 26                                                     k2         1000
# 27                                            ethan allen         1000
# 28                                                    ply         1000
# 29                                                 horton          400
# ...                                                   ...          ...
# 216900                                       alec baldwin          400
# 216901                                             samson          400
# 216902                                           the teal          400
# 216903                                             africa          400
# 216904                                      ronald reagan          400
# 216905                                           budapest          800
# 216906                                          amsterdam          800
# 216907                                                man          800
# 216908                                           a toucan          800
# 216909                                     allen ginsberg          800
# 216910                                       muhammad ali          800
# 216911                                               oslo         1200
# 216912                                         siddhartha         1200
# 216913                                       edward elgar         1200
# 216914                                             a tern         1200
# 216915                               erle stanley gardner         1200
# 216916                                               work         2200
# 216917                                         georgetown         3400
# 216918                                         fanny hill         1600
# 216919                                           magritte         1600
# 216920                                           thrushes         1600
# 216921                                           anas nin         1600
# 216922                                  margaret thatcher         1600
# 216923                                         paramaribo         2000
# 216924                                              stomp         2000
# 216925                                           turandot         2000
# 216926                                         a titmouse         2000
# 216927                                       clive barker         2000
# 216928                                           geronimo         2000
# 216929                     grigori alexandrovich potemkin            0
#
# [216930 rows x 10 columns]

# %%
# check the datatype for each column
jeopardy.dtypes
# Out:
# Show Number                int64
# Air Date          datetime64[ns]
# Round                     object
# Category                  object
# Value                     object
# Question                  object
# Answer                    object
# clean_question            object
# clean_answer              object
# clean_value                int64
# dtype: object

# %%
# How often the answer is deducible from the question.
# We can answer the question by seeing how many times words in the answer also occur in the question. 

# Write a function that takes in a row in jeopardy, as a Series. It should:
def answer_deductible(row):
    # Split the clean_answer column on the space character (), and assign to the variable split_answer.
    split_answer = row["clean_answer"].split(" ")
    # Split the clean_question column on the space character (), and assign to the variable split_question.
    split_question = row["clean_question"].split(" ")
    # If "the" is in split_answer, remove it using the remove method on lists. "The" is commonly found in answers and questions, but doesn't have any meaningful use in finding the answer.
    if "the" in split_answer:
        split_answer.remove("the")
    # If the length of split_answer is 0, return 0. This prevents a division by zero error later.
    if len(split_answer) == 0:
        return 0
    # Create a variable called match_count, and set it to 0.
    match_count = 0
    # Loop through each item in split_answer, and see if it occurs in split_question. If it does, add 1 to match_count.
    for item in split_answer:
        if item in split_question:
            match_count += 1
    # Divide match_count by the length of split_answer, and return the result.
    result = match_count / len(split_answer)
    return result

# %%
# Count how many times terms in clean_answer occur in clean_question
jeopardy["answer_in_question"] = jeopardy.apply(answer_deductible, axis=1)
print(jeopardy.head())
# Out:
#    Show Number   Air Date      Round                         Category  Value  \
# 0         4680 2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680 2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams
#
#                                       clean_question clean_answer  \
# 0  for the last 8 years of his life galileo was u...   copernicus
# 1  no 2 1912 olympian football star at carlisle i...   jim thorpe
# 2  the city of yuma in this state has a record av...      arizona
# 3  in 1963 live on the art linkletter show this c...    mcdonalds
# 4  signer of the dec of indep framer of the const...   john adams
#
#    clean_value  answer_in_question
# 0          200                 0.0
# 1          200                 0.0
# 2          200                 0.0
# 3          200                 0.0
# 4          200                 0.0

# %%
# Find the mean of the answer_in_question column using the mean method on Series.
mean_answer_inquestion = jeopardy["answer_in_question"].mean()
print(mean_answer_inquestion)
# Out:
# 0.0593714165298

# %% [markdown]
# Answer terms in the question
#
# The answer only appears in the question about 6% of the time. This isn't a huge number, and means that we probably can't just hope that hearing a question will enable us to figure out the answer. We'll probably have to study.

# %%
# Recycled Questions
# investigate how often new questions are repeats of older ones.

# Sort jeopardy in order of ascending air date.
jeopardy.sort_values("Air Date", ascending = True)
# Out:
#         Show Number   Air Date             Round                 Category  \
# 84523             1 1984-09-10         Jeopardy!           LAKES & RIVERS
# 84565             1 1984-09-10  Double Jeopardy!                THE BIBLE
# 84566             1 1984-09-10  Double Jeopardy!                 '50'S TV
# 84567             1 1984-09-10  Double Jeopardy!       NATIONAL LANDMARKS
# 84568             1 1984-09-10  Double Jeopardy!                NOTORIOUS
# 84569             1 1984-09-10  Double Jeopardy!           4-LETTER WORDS
# 84570             1 1984-09-10   Final Jeopardy!                 HOLIDAYS
# 84538             1 1984-09-10         Jeopardy!           LAKES & RIVERS
# 84537             1 1984-09-10         Jeopardy!           ACTORS & ROLES
# 84536             1 1984-09-10         Jeopardy!          FOREIGN CUISINE
# 84564             1 1984-09-10  Double Jeopardy!           4-LETTER WORDS
# 84535             1 1984-09-10         Jeopardy!                  ANIMALS
# 84533             1 1984-09-10         Jeopardy!           LAKES & RIVERS
# 84532             1 1984-09-10         Jeopardy!           ACTORS & ROLES
# 84531             1 1984-09-10         Jeopardy!          FOREIGN CUISINE
# 84530             1 1984-09-10         Jeopardy!                  ANIMALS
# 84529             1 1984-09-10         Jeopardy!               INVENTIONS
# 84528             1 1984-09-10         Jeopardy!           LAKES & RIVERS
# 84527             1 1984-09-10         Jeopardy!           ACTORS & ROLES
# 84526             1 1984-09-10         Jeopardy!          FOREIGN CUISINE
# 84525             1 1984-09-10         Jeopardy!                  ANIMALS
# 84534             1 1984-09-10         Jeopardy!               INVENTIONS
# 84524             1 1984-09-10         Jeopardy!               INVENTIONS
# 84563             1 1984-09-10  Double Jeopardy!       NATIONAL LANDMARKS
# 84561             1 1984-09-10  Double Jeopardy!                THE BIBLE
# 84549             1 1984-09-10  Double Jeopardy!                NOTORIOUS
# 84548             1 1984-09-10  Double Jeopardy!       NATIONAL LANDMARKS
# 84547             1 1984-09-10  Double Jeopardy!                 '50'S TV
# 84546             1 1984-09-10  Double Jeopardy!                THE BIBLE
# 84545             1 1984-09-10         Jeopardy!           ACTORS & ROLES
# ...             ...        ...               ...                      ...
# 105932         6300 2012-01-27         Jeopardy!           STUPID ANSWERS
# 105931         6300 2012-01-27         Jeopardy!             CHILD ACTORS
# 105953         6300 2012-01-27         Jeopardy!        VISITING THE CITY
# 105958         6300 2012-01-27         Jeopardy!   THE TRUTH LIES THEREIN
# 105957         6300 2012-01-27         Jeopardy!  LESSER-KNOWN SCIENTISTS
# 105956         6300 2012-01-27         Jeopardy!           STUPID ANSWERS
# 105955         6300 2012-01-27         Jeopardy!             CHILD ACTORS
# 105954         6300 2012-01-27         Jeopardy!                    PANTS
# 105952         6300 2012-01-27         Jeopardy!   THE TRUTH LIES THEREIN
# 105938         6300 2012-01-27         Jeopardy!           STUPID ANSWERS
# 105950         6300 2012-01-27         Jeopardy!           STUPID ANSWERS
# 105943         6300 2012-01-27         Jeopardy!             CHILD ACTORS
# 105929         6300 2012-01-27         Jeopardy!        VISITING THE CITY
# 105942         6300 2012-01-27         Jeopardy!                    PANTS
# 105941         6300 2012-01-27         Jeopardy!        VISITING THE CITY
# 105940         6300 2012-01-27         Jeopardy!   THE TRUTH LIES THEREIN
# 105939         6300 2012-01-27         Jeopardy!  LESSER-KNOWN SCIENTISTS
# 105937         6300 2012-01-27         Jeopardy!             CHILD ACTORS
# 105936         6300 2012-01-27         Jeopardy!                    PANTS
# 105935         6300 2012-01-27         Jeopardy!        VISITING THE CITY
# 105934         6300 2012-01-27         Jeopardy!   THE TRUTH LIES THEREIN
# 105933         6300 2012-01-27         Jeopardy!  LESSER-KNOWN SCIENTISTS
# 105944         6300 2012-01-27         Jeopardy!           STUPID ANSWERS
# 105945         6300 2012-01-27         Jeopardy!  LESSER-KNOWN SCIENTISTS
# 105946         6300 2012-01-27         Jeopardy!   THE TRUTH LIES THEREIN
# 105947         6300 2012-01-27         Jeopardy!        VISITING THE CITY
# 105948         6300 2012-01-27         Jeopardy!                    PANTS
# 105949         6300 2012-01-27         Jeopardy!             CHILD ACTORS
# 105951         6300 2012-01-27         Jeopardy!  LESSER-KNOWN SCIENTISTS
# 105930         6300 2012-01-27         Jeopardy!                    PANTS
#
#           Value                                           Question  \
# 84523     $100             River mentioned most often in the Bible
# 84565   $1,000   According to 1st Timothy, it is the "root of a...
# 84566   $1,000   Name under which experimenter Don Herbert taug...
# 84567   $1,000     D.C. building shaken by November '83 bomb blast
# 84568   $1,000   After the deed, he leaped to the stage shoutin...
# 84569   $1,000   The president takes one before stepping into o...
# 84570      None       The third Monday of January starting in 1986
# 84538     $400   American river only 33 miles shorter than the ...
# 84537     $300   He may "Never Say Never Again" when asked to b...
# 84536     $300                     Jewish crepe filled with cheese
# 84564   $1,000   It's the first 4-letter word in "The Star Span...
# 84535     $300   When husbands "pop" for an ermine coat, they'r...
# 84533     $800   River in <a href="http://www.j-archive.com/med...
# 84532     $200   2 "Saturday Night" alumni who tried "Trading P...
# 84531     $200   A British variety is called "bangers", a Mexic...
# 84530     $200   There are about 40,000 muscles & tendons in th...
# 84529     $200   In 1869 an American minister created this "ori...
# 84528     $200                              Scottish word for lake
# 84527     $100   Video in which Michael Jackson plays a werewol...
# 84526     $100                             The "coq" in coq au vin
# 84525     $100   These rodents first got to America by stowing ...
# 84534     $300   A 1920's hunting trip to Canada inspired Birds...
# 84524     $100                        Marconi's wonderful wireless
# 84563     $800   Site where John Hancock signed his "John Hancock"
# 84561     $800   Though its name means "city of peace", it's se...
# 84549     $200   It was probably a lyre, not a fiddle, if he pl...
# 84548     $200    She came from France to harbor America's freedom
# 84547     $200   Occupation of Richard Diamond, Peter Gunn & Mi...
# 84546     $200   When "Joshua Fit The Battle Of Jericho", these...
# 84545     $500   Sam Shepard played this barrier breaker in "Th...
# ...         ...                                                ...
# 105932    $200   On the west, Central Park is bounded by this s...
# 105931    $200   Henry Thomas, who played this role in "E.T.", ...
# 105953  $1,000   Arriving at the train station built for the 19...
# 105958  $1,000               A palindromic preposition of the past
# 105957  $1,000   In 1785 William Withering suggested using this...
# 105956  $1,000   The Mosquito Indians are a majority population...
# 105955  $1,000   In the 1930s Baby LeRoy played opposite this c...
# 105954  $1,000   The baggy shalwar is always in fashion in this...
# 105952    $800                                     Colt controller
# 105938    $400   This building in our national capital was orig...
# 105950    $800   The second verse of this classic American song...
# 105943    $600   At age 11, this future portrayer of Bella Swan...
# 105929    $200   Experience Little Havana along Calle Ocho, the...
# 105942    $600   When introduced, these wide, baggy pants were ...
# 105941    $600   Take the "Sound of Music" tour or visit the Ha...
# 105940    $400   Old school GPS on a shopping mall map:  "You A...
# 105939    $400   The "crown jewels" of Alcoa are the bits of th...
# 105937    $400   Scott Lookinland played his father, Mike, in t...
# 105936    $400   Calf-length pants styled in colorful island pr...
# 105935    $400   First the Royal Ontario Museum, then for lunch...
# 105934    $200              Symbol for the second-lightest element
# 105933    $200   In 1779 Dutch scientist Jan Ingenhousz publish...
# 105944    $600   This was first imprinted in black on individua...
# 105945    $600   Gowin Knight's 1745 development of a better wa...
# 105946    $600        Old school CBS history show:  "You Are" this
# 105947    $800   There's a great opera house on Bennelong Point...
# 105948  $1,400   Tight-fitting pants patterned after those worn...
# 105949    $800   This kid, with a familiar last name, is seen <...
# 105951    $800   Joseph Lagrange insisted on 10 as the basic un...
# 105930    $200   A synonym for freight, or pants with large bel...
#
#                                       Answer  \
# 84523                             the Jordan
# 84565                      the love of money
# 84566                             Mr. Wizard
# 84567                            the Capitol
# 84568                      John Wilkes Booth
# 84569                                   oath
# 84570                 Martin Luther King Day
# 84538                           the Missouri
# 84537                           Sean Connery
# 84536                               a blintz
# 84564                                   what
# 84535                                 weasel
# 84533                        the Volga River
# 84532             Dan Aykroyd & Eddie Murphy
# 84531                                sausage
# 84530                              the trunk
# 84529                           the rickshaw
# 84528                                   loch
# 84527                             "Thriller"
# 84526                                chicken
# 84525                                   rats
# 84534                               freezing
# 84524                              the radio
# 84563                      Independence Hall
# 84561                              Jerusalem
# 84549                                   Nero
# 84548                  the Statue of Liberty
# 84547   private eyes (or private detectives)
# 84546                              the walls
# 84545                   Colonel Chuck Yeager
# ...                                      ...
# 105932                     Central Park West
# 105931                               Elliott
# 105953                               Seville
# 105958                                   ere
# 105957                digitalis (or digoxin)
# 105956                    the Mosquito Coast
# 105955                          W. C. Fields
# 105954                              Pakistan
# 105952                                  rein
# 105938                           the Capitol
# 105950               "America the Beautiful"
# 105943                       Kristen Stewart
# 105929                                 Miami
# 105942                            plus fours
# 105941                              Salzburg
# 105940                                  here
# 105939                              aluminum
# 105937                       The Brady Bunch
# 105936                            luau pants
# 105935                               Toronto
# 105934                                    He
# 105933                        photosynthesis
# 105944                                     M
# 105945                             a compass
# 105946                                 There
# 105947                                Sydney
# 105948                        toreador pants
# 105949                           Jaden Smith
# 105951                     the metric system
# 105930                           cargo pants
#
#                                            clean_question  \
# 84523             river mentioned most often in the bible
# 84565   according to 1st timothy it is the root of all...
# 84566   name under which experimenter don herbert taug...
# 84567        dc building shaken by november 83 bomb blast
# 84568   after the deed he leaped to the stage shouting...
# 84569   the president takes one before stepping into o...
# 84570        the third monday of january starting in 1986
# 84538   american river only 33 miles shorter than the ...
# 84537   he may never say never again when asked to be ...
# 84536                     jewish crepe filled with cheese
# 84564   its the first 4letter word in the star spangle...
# 84535   when husbands pop for an ermine coat theyre ac...
# 84533   river in a hrefhttpwwwjarchivecommedia19840910...
# 84532    2 saturday night alumni who tried trading places
# 84531   a british variety is called bangers a mexican ...
# 84530   there are about 40000 muscles  tendons in this...
# 84529   in 1869 an american minister created this orie...
# 84528                              scottish word for lake
# 84527   video in which michael jackson plays a werewol...
# 84526                               the coq in coq au vin
# 84525   these rodents first got to america by stowing ...
# 84534   a 1920s hunting trip to canada inspired birdse...
# 84524                         marconis wonderful wireless
# 84563     site where john hancock signed his john hancock
# 84561   though its name means city of peace its seen o...
# 84549   it was probably a lyre not a fiddle if he play...
# 84548     she came from france to harbor americas freedom
# 84547   occupation of richard diamond peter gunn  mike...
# 84546   when joshua fit the battle of jericho these to...
# 84545   sam shepard played this barrier breaker in the...
# ...                                                   ...
# 105932  on the west central park is bounded by this st...
# 105931  henry thomas who played this role in et turned...
# 105953  arriving at the train station built for the 19...
# 105958              a palindromic preposition of the past
# 105957  in 1785 william withering suggested using this...
# 105956  the mosquito indians are a majority population...
# 105955  in the 1930s baby leroy played opposite this c...
# 105954  the baggy shalwar is always in fashion in this...
# 105952                                    colt controller
# 105938  this building in our national capital was orig...
# 105950  the second verse of this classic american song...
# 105943  at age 11 this future portrayer of bella swan ...
# 105929  experience little havana along calle ocho then...
# 105942  when introduced these wide baggy pants were 4 ...
# 105941  take the sound of music tour or visit the hage...
# 105940  old school gps on a shopping mall map  you are...
# 105939  the crown jewels of alcoa are the bits of this...
# 105937  scott lookinland played his father mike in the...
# 105936  calflength pants styled in colorful island pri...
# 105935  first the royal ontario museum then for lunch ...
# 105934              symbol for the secondlightest element
# 105933  in 1779 dutch scientist jan ingenhousz publish...
# 105944  this was first imprinted in black on individua...
# 105945  gowin knights 1745 development of a better way...
# 105946          old school cbs history show  you are this
# 105947  theres a great opera house on bennelong point ...
# 105948  tightfitting pants patterned after those worn ...
# 105949  this kid with a familiar last name is seen a h...
# 105951  joseph lagrange insisted on 10 as the basic un...
# 105930  a synonym for freight or pants with large bell...
#
#                               clean_answer  clean_value  answer_in_question
# 84523                           the jordan          100            0.000000
# 84565                    the love of money         1000            0.333333
# 84566                            mr wizard         1000            0.000000
# 84567                          the capitol         1000            0.000000
# 84568                    john wilkes booth         1000            0.000000
# 84569                                 oath         1000            0.000000
# 84570               martin luther king day            0            0.000000
# 84538                         the missouri          400            0.000000
# 84537                         sean connery          300            0.000000
# 84536                             a blintz          300            0.000000
# 84564                                 what         1000            0.000000
# 84535                               weasel          300            0.000000
# 84533                      the volga river          800            0.500000
# 84532            dan aykroyd  eddie murphy          200            0.000000
# 84531                              sausage          200            0.000000
# 84530                            the trunk          200            0.000000
# 84529                         the rickshaw          200            0.000000
# 84528                                 loch          200            0.000000
# 84527                             thriller          100            0.000000
# 84526                              chicken          100            0.000000
# 84525                                 rats          100            0.000000
# 84534                             freezing          300            0.000000
# 84524                            the radio          100            0.000000
# 84563                    independence hall          800            0.000000
# 84561                            jerusalem          800            0.000000
# 84549                                 nero          200            0.000000
# 84548                the statue of liberty          200            0.000000
# 84547   private eyes or private detectives          200            0.000000
# 84546                            the walls          200            0.000000
# 84545                 colonel chuck yeager          500            0.000000
# ...                                    ...          ...                 ...
# 105932                   central park west          200            1.000000
# 105931                             elliott          200            0.000000
# 105953                             seville         1000            0.000000
# 105958                                 ere         1000            0.000000
# 105957                digitalis or digoxin         1000            0.000000
# 105956                  the mosquito coast         1000            0.500000
# 105955                          w c fields         1000            0.000000
# 105954                            pakistan         1000            0.000000
# 105952                                rein          800            0.000000
# 105938                         the capitol          400            0.000000
# 105950               america the beautiful          800            0.500000
# 105943                     kristen stewart          600            0.000000
# 105929                               miami          200            0.000000
# 105942                          plus fours          600            0.000000
# 105941                            salzburg          600            0.000000
# 105940                                here          400            0.000000
# 105939                            aluminum          400            0.000000
# 105937                     the brady bunch          400            0.000000
# 105936                          luau pants          400            0.500000
# 105935                             toronto          400            0.000000
# 105934                                  he          200            0.000000
# 105933                      photosynthesis          200            0.000000
# 105944                                   m          600            0.000000
# 105945                           a compass          600            0.500000
# 105946                               there          600            0.000000
# 105947                              sydney          800            0.000000
# 105948                      toreador pants         1400            0.500000
# 105949                         jaden smith          800            0.000000
# 105951                   the metric system          800            0.500000
# 105930                         cargo pants          200            0.500000
#
# [216930 rows x 11 columns]

# %% [markdown]
# Below step enable you to check if the terms in questions have been used previously or not.
# Only looking at words greater than 6 characters enables you to filter out words like the and than,
# which are commonly used, but don't tell you a lot about a question.

# %%
# Maintain a set called terms_used that will be empty initially
terms_used = set()
# Create an empty list called question_overlap
question_overlap = []

# Iterate through each row of jeopardy.
# DataFrame.iterrows() -> Iterate over DataFrame rows as (index, Series) pairs.
for i, row in jeopardy.iterrows():
    # Split clean_question into words, remove any word shorter than 6 characters, and check if each word occurs in terms_used.
    split_question = row["clean_question"].split(" ")
    split_question = [i for i in split_question if len(i) > 5]
    # Set counter to 0
    morethan6charc_count = 0
    for word in split_question:
        # If it does, increment a counter.
        if word in terms_used:
            morethan6charc_count += 1
    # add each word to terms_used. (set.add() can add element to set data type)
    for word in split_question:
        terms_used.add(word)
    # If the length of split_question is greater than 0, divide match_count by the length of split_question.
    if len(split_question) > 0:
        morethan6charc_count = morethan6charc_count / len(split_question)
    # Append match_count to question_overlap.
    question_overlap.append(morethan6charc_count)

# %%
# Assign question_overlap to the question_overlap column of jeopardy
jeopardy["question_overlap"] = question_overlap

# Find the mean of the question_overlap column and print it.
mean_questionoverlap = jeopardy["question_overlap"].mean()
print(mean_questionoverlap)
# Out:
# 0.873511019215

# %% [markdown]
# Question overlap
#
# There is about 87% overlap between terms in new questions and terms in old questions. This only looks at a small set of questions, and it doesn't look at phrases, it looks at single terms. This makes it relatively insignificant, but it does mean that it's worth looking more into the recycling of questions.

# %%
# Low Value Vs High Value Questions
# you only want to study questions that pertain to high value questions instead of low value questions.
# We can figure out which terms correspond to high-value questions using a chi-squared test
# First, narrow down the questions into two categories
# Then loop through each of the terms from the last screen, terms_used
"""
1. Find the number of low value questions the word occurs in.
2. Find the number of high value questions the word occurs in.
3. Find the percentage of questions the word occurs in.
4. Based on the percentage of questions the word occurs in, find expected counts.
5. Compute the chi squared value based on the expected counts and the observed counts for high and low value questions.
"""

# Create a function that takes in a row from a Dataframe
def value_group(row):
    # If the clean_value column is greater than 800, assign 1 to value.
    if row["clean_value"] > 800:
        value = 1
    # Otherwise, assign 0 to value.
    else:
        value = 0
    # Return value.
    return value

jeopardy["high_value"] = jeopardy.apply(value_group, axis=1)

# %%
# Create a function that takes in a word
def group_word_count(word):
    low_count = 0
    high_count = 0
    for i, row in jeopardy.iterrows():
        # If the word is in the split question
        if word in row["clean_question"].split(" "):
            if row["high_value"] == 1:
                high_count += 1
            else:
                low_count += 1
    return high_count, low_count

# %%
observed_expected = []

# Convert terms_used into a list using the list function, and assign the first 5 elements to comparison_terms.
comparison_terms = list(terms_used)[:5]

# %%
# Loop through each term in comparison_terms, and:
# Run the function on the term to get the high value and low value counts.
# Append the result of running the function (which will be a list) to observed_expected.
for term in comparison_terms:
    observed_expected.append(group_word_count(term))
    
observed_expected
# Out:
# [(0, 1), (0, 1), (0, 1), (0, 1), (33, 83)]

# %%
# Applying The Chi-Squared Test

# Find the number of rows in jeopardy where high_value is 1
high_value_count = jeopardy[jeopardy["high_value"] == 1].shape[0]

# Find the number of rows in jeopardy where high_value is 0
low_value_count = jeopardy[jeopardy["high_value"] == 0].shape[0]

# %%
import numpy as np
from scipy.stats import chisquare

chi_squared = []

# Loop through each list in observed_expected
for lists in observed_expected:
    # Add up both items in the list (high and low counts) to get the total count, and assign to total.
    total = sum(lists)
    # Divide total by the number of rows in jeopardy to get the proportion across the dataset. Assign to total_prop.
    total_prop = total / jeopardy.shape[0]
    # Multiply total_prop by high_value_count to get the expected term count for high value rows.
    total_high_prop = total_prop * high_value_count
    # Multiply total_prop by low_value_count to get the expected term count for low value rows.
    total_low_prop = total_prop * low_value_count
    
    # Use the scipy.stats.chisquare function to compute the chi-squared value and p-value given the expected and observed counts.
    observed = np.array([lists[0], lists[1]])
    expected = np.array([total_high_prop, total_low_prop])
    chi_squared.append(chisquare(observed, expected))
    # Append the results to chi_squared.

chi_squared
# Out:
# [Power_divergenceResult(statistic=0.39497646423335131, pvalue=0.52969509124866954),
#  Power_divergenceResult(statistic=0.39497646423335131, pvalue=0.52969509124866954),
#  Power_divergenceResult(statistic=0.39497646423335131, pvalue=0.52969509124866954),
#  Power_divergenceResult(statistic=0.39497646423335131, pvalue=0.52969509124866954),
#  Power_divergenceResult(statistic=0.0010273158506472991, pvalue=0.97443076695468012)]

# %% [markdown]
# Chi-squared results
#
# None of the terms had a significant difference in usage between high value and low value rows (pvalue all greater than 0.05). Additionally, the frequencies were lower than 5 for 4 of the terms, so the chi-squared test isn't as valid. It would be better to run this test with only terms that have higher frequencies.
